# %% [markdown]
# <a href="https://colab.research.google.com/github/Stesilva16/Eng-de-dados--/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação das bibliotecas

# %%
pip install pandera
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandera in /usr/local/lib/python3.7/dist-packages (0.13.4)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (1.21.6)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (1.3.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (21.3)
# Requirement already satisfied: typing-inspect>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (0.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from pandera) (4.1.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.7/dist-packages (from pandera) (1.14.1)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.7/dist-packages (from pandera) (1.10.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->pandera) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pandera) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pandera) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pandera) (1.15.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.6.0->pandera) (0.4.3)

# %%
import pandas as pd
import pandera as pa
import numpy as np

# %%
pd.set_option('display.max_columns',100)
#pd.set_option('display.max_rows')

# %% [markdown]
# # Extração das bases de dados

# %%
df = pd.read_csv('https://storage.googleapis.com/bc26-bucket/ocorrencia.csv',sep=';',encoding = 'ISO-8859-1', parse_dates=['ocorrencia_dia'], dayfirst = True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 81027               81027               81027
# 1                 81030               81030               81030
# 2                 81023               81023               81023
# 3                 81029               81029               81029
# 4                 81025               81025               81025
# ...                 ...                 ...                 ...
# 6764              40324               40324               40324
# 6765              39527               39527               39527
# 6766              40211               40211               40211
# 6767              40349               40349               40349
# 6768              40351               40351               40351
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  81027               81027          INCIDENTE GRAVE
# 1                  81030               81030                INCIDENTE
# 2                  81023               81023          INCIDENTE GRAVE
# 3                  81029               81029                INCIDENTE
# 4                  81025               81025                INCIDENTE
# ...                  ...                 ...                      ...
# 6764               40324               40324                INCIDENTE
# 6765               39527               39527                 ACIDENTE
# 6766               40211               40211                INCIDENTE
# 6767               40349               40349                INCIDENTE
# 6768               40351               40351                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 0                    NaN                  NaN           SÃO PAULO
# 1                    NaN                  NaN             VITÓRIA
# 2                    NaN                  NaN           AMERICANA
# 3                    NaN                  NaN      BELO HORIZONTE
# 4                    NaN                  NaN              MANAUS
# ...                  ...                  ...                 ...
# 6764                 NaN                  NaN             PELOTAS
# 6765      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE
# 6766                 ***                  ***      RIO DE JANEIRO
# 6767                 NaN                  NaN               BELÉM
# 6768                 NaN                  NaN      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia  \
# 0               SP          BRASIL                 SBSP     2022-10-09
# 1               ES          BRASIL                 SBVT     2022-10-09
# 2               SP          BRASIL                 SDAI     2022-10-06
# 3               MG          BRASIL                 SBBH     2022-10-06
# 4               AM          BRASIL                 SBEG     2022-10-05
# ...            ...             ...                  ...            ...
# 6764            RS          BRASIL                 SBPK     2010-01-05
# 6765            MT          BRASIL                  ***     2010-01-04
# 6766            RJ          BRASIL                  ***     2010-01-03
# 6767            PA          BRASIL                 SBBE     2010-01-03
# 6768            RJ          BRASIL                 SBRJ     2010-01-03
#
#      ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 0           16:30:00                            SIM               ATIVA
# 1           16:20:00                            SIM               ATIVA
# 2           15:30:00                            SIM          FINALIZADA
# 3           00:44:00                            SIM          FINALIZADA
# 4           20:56:00                            SIM          FINALIZADA
# ...              ...                            ...                 ...
# 6764        19:25:00                            SIM          FINALIZADA
# 6765        17:30:00                            SIM          FINALIZADA
# 6766        12:00:00                            SIM          FINALIZADA
# 6767        11:05:00                            SIM          FINALIZADA
# 6768        03:00:00                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                      A DEFINIR                            NÃO
# 1                      A DEFINIR                            NÃO
# 2                            ***                            NÃO
# 3                            ***                            NÃO
# 4                            ***                            NÃO
# ...                          ...                            ...
# 6764                         NaN                            NÃO
# 6765           A-539/CENIPA/2018                            SIM
# 6766                         ***                            NÃO
# 6767                         NaN                            NÃO
# 6768                         NaN                            NÃO
#
#      divulgacao_dia_publicacao  total_recomendacoes  \
# 0                          NaN                    0
# 1                          NaN                    0
# 2                          NaN                    0
# 3                          NaN                    0
# 4                          NaN                    0
# ...                        ...                  ...
# 6764                       NaN                    0
# 6765                2019-10-28                    0
# 6766                       NaN                    0
# 6767                       NaN                    0
# 6768                       NaN                    0
#
#       total_aeronaves_envolvidas ocorrencia_saida_pista
# 0                              1                    SIM
# 1                              1                    NÃO
# 2                              1                    SIM
# 3                              1                    NÃO
# 4                              1                    NÃO
# ...                          ...                    ...
# 6764                           1                    NÃO
# 6765                           1                    NÃO
# 6766                           1                    NÃO
# 6767                           1                    NÃO
# 6768                           1                    NÃO
#
# [6769 rows x 22 columns]

# %% [markdown]
# # Pré-analise

# %%
df.head(2)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              81027               81027               81027
# 1              81030               81030               81030
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               81027               81027          INCIDENTE GRAVE
# 1               81030               81030                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                 NaN                  NaN         SÃO PAULO            SP
# 1                 NaN                  NaN           VITÓRIA            ES
#
#   ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0          BRASIL                 SBSP     2022-10-09        16:30:00
# 1          BRASIL                 SBVT     2022-10-09        16:20:00
#
#   investigacao_aeronave_liberada investigacao_status  \
# 0                            SIM               ATIVA
# 1                            SIM               ATIVA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                   A DEFINIR                            NÃO
# 1                   A DEFINIR                            NÃO
#
#   divulgacao_dia_publicacao  total_recomendacoes  total_aeronaves_envolvidas  \
# 0                       NaN                    0                           1
# 1                       NaN                    0                           1
#
#   ocorrencia_saida_pista
# 0                    SIM
# 1                    NÃO

# %%
df.tail(2)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 6767              40349               40349               40349
# 6768              40351               40351               40351
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 6767               40349               40349                INCIDENTE
# 6768               40351               40351                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 6767                 NaN                  NaN             BELÉM            PA
# 6768                 NaN                  NaN    RIO DE JANEIRO            RJ
#
#      ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 6767          BRASIL                 SBBE     2010-01-03        11:05:00
# 6768          BRASIL                 SBRJ     2010-01-03        03:00:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 6767                            SIM          FINALIZADA
# 6768                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 6767                         NaN                            NÃO
# 6768                         NaN                            NÃO
#
#      divulgacao_dia_publicacao  total_recomendacoes  \
# 6767                       NaN                    0
# 6768                       NaN                    0
#
#       total_aeronaves_envolvidas ocorrencia_saida_pista
# 6767                           1                    NÃO
# 6768                           1                    NÃO

# %%
df.dtypes
# Out:
# codigo_ocorrencia                          int64
# codigo_ocorrencia1                         int64
# codigo_ocorrencia2                         int64
# codigo_ocorrencia3                         int64
# codigo_ocorrencia4                         int64
# ocorrencia_classificacao                  object
# ocorrencia_latitude                       object
# ocorrencia_longitude                      object
# ocorrencia_cidade                         object
# ocorrencia_uf                             object
# ocorrencia_pais                           object
# ocorrencia_aerodromo                      object
# ocorrencia_dia                    datetime64[ns]
# ocorrencia_hora                           object
# investigacao_aeronave_liberada            object
# investigacao_status                       object
# divulgacao_relatorio_numero               object
# divulgacao_relatorio_publicado            object
# divulgacao_dia_publicacao                 object
# total_recomendacoes                        int64
# total_aeronaves_envolvidas                 int64
# ocorrencia_saida_pista                    object
# dtype: object

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              81027               81027               81027
# 1              81030               81030               81030
# 2              81023               81023               81023
# 3              81029               81029               81029
# 4              81025               81025               81025
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               81027               81027          INCIDENTE GRAVE
# 1               81030               81030                INCIDENTE
# 2               81023               81023          INCIDENTE GRAVE
# 3               81029               81029                INCIDENTE
# 4               81025               81025                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                 NaN                  NaN         SÃO PAULO            SP
# 1                 NaN                  NaN           VITÓRIA            ES
# 2                 NaN                  NaN         AMERICANA            SP
# 3                 NaN                  NaN    BELO HORIZONTE            MG
# 4                 NaN                  NaN            MANAUS            AM
#
#   ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0          BRASIL                 SBSP     2022-10-09        16:30:00
# 1          BRASIL                 SBVT     2022-10-09        16:20:00
# 2          BRASIL                 SDAI     2022-10-06        15:30:00
# 3          BRASIL                 SBBH     2022-10-06        00:44:00
# 4          BRASIL                 SBEG     2022-10-05        20:56:00
#
#   investigacao_aeronave_liberada investigacao_status  \
# 0                            SIM               ATIVA
# 1                            SIM               ATIVA
# 2                            SIM          FINALIZADA
# 3                            SIM          FINALIZADA
# 4                            SIM          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                   A DEFINIR                            NÃO
# 1                   A DEFINIR                            NÃO
# 2                         ***                            NÃO
# 3                         ***                            NÃO
# 4                         ***                            NÃO
#
#   divulgacao_dia_publicacao  total_recomendacoes  total_aeronaves_envolvidas  \
# 0                       NaN                    0                           1
# 1                       NaN                    0                           1
# 2                       NaN                    0                           1
# 3                       NaN                    0                           1
# 4                       NaN                    0                           1
#
#   ocorrencia_saida_pista
# 0                    SIM
# 1                    NÃO
# 2                    SIM
# 3                    NÃO
# 4                    NÃO

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %% [markdown]
# ## Tratamentos de dados

# %%
#backup do dataframe original
dfback = df.copy()

# %% [markdown]
# df.drop(['codigo_ocorrencia1','codigo_ocorrencia2','codigo_ocorrencia3','codigo_ocorrencia4'],axis=1,inplace=True)

# %%
df.head(1)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              81027               81027               81027
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               81027               81027          INCIDENTE GRAVE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                 NaN                  NaN         SÃO PAULO            SP
#
#   ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0          BRASIL                 SBSP     2022-10-09        16:30:00
#
#   investigacao_aeronave_liberada investigacao_status  \
# 0                            SIM               ATIVA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                   A DEFINIR                            NÃO
#
#   divulgacao_dia_publicacao  total_recomendacoes  total_aeronaves_envolvidas  \
# 0                       NaN                    0                           1
#
#   ocorrencia_saida_pista
# 0                    SIM

# %% [markdown]
# # drop de colunas
#
# ocorrencia_latitude , ocorrencia_longitude , investigacao_aeronave_liberada , investigacao_status , divulgacao_relatorio_numero , divulgacao_relatorio_publicado, divulgacao_dia_publicacao , codigo_ocorrencia1,codigo_ocorrencia2,codigo_ocorrencia3,codigo_ocorrencia4

# %%
#Dropagem das colunas que tinham dados repetidos
df.drop(['codigo_ocorrencia1','codigo_ocorrencia2','codigo_ocorrencia3','codigo_ocorrencia4'],axis=1,inplace=True)

# %%
#Drop de colunas que não serão utilizadas
df.drop(['ocorrencia_latitude','ocorrencia_longitude','investigacao_aeronave_liberada','investigacao_status','divulgacao_relatorio_numero','divulgacao_relatorio_publicado','divulgacao_dia_publicacao'],axis=1,inplace=True)

# %%
df.dtypes
# Out:
# codigo_ocorrencia                      int64
# ocorrencia_classificacao              object
# ocorrencia_cidade                     object
# ocorrencia_uf                         object
# ocorrencia_pais                       object
# ocorrencia_aerodromo                  object
# ocorrencia_dia                datetime64[ns]
# ocorrencia_hora                       object
# total_recomendacoes                    int64
# total_aeronaves_envolvidas             int64
# ocorrencia_saida_pista                object
# dtype: object

# %%
#Renomear as colunas

df.rename(columns={'codigo_ocorrencia':'ocorrencia','ocorrencia_classificacao':'classificacao','ocorrencia_cidade':'cidade','ocorrencia_uf':'uf','ocorrencia_pais':'pais','ocorrencia_aerodromo':'aerodromo'},inplace=True)
df.rename(columns={'ocorrencia_dia':'dia','ocorrencia_hora':'horario','total_recomendacoes':'recomendacoes','total_aeronaves_envolvidas':'n_aeronaves','ocorrencia_saida_pista':'saida_pista'},inplace=True)

# %%
df.dtypes
# Out:
# ocorrencia                int64
# classificacao            object
# cidade                   object
# uf                       object
# pais                     object
# aerodromo                object
# dia              datetime64[ns]
# horario                  object
# recomendacoes             int64
# n_aeronaves               int64
# saida_pista              object
# dtype: object

# %%
pd.unique(df['classificacao'])
# Out:
# array(['INCIDENTE GRAVE', 'INCIDENTE', 'ACIDENTE'], dtype=object)

# %%
sorted(pd.unique(df['saida_pista']))
# Out:
# ['NÃO', 'SIM']

# %% [markdown]
# inconsistencia encontradas ***, **NI

# %%
df.replace(['***','**NI'],pd.NA, inplace=True)

# %%
df.tail(10)
# Out:
#       ocorrencia    classificacao              cidade  uf    pais aerodromo  \
# 6759       40069         ACIDENTE           SÃO PAULO  SP  BRASIL      SBMT
# 6760       40414        INCIDENTE            BRASÍLIA  DF  BRASIL      SBBR
# 6761       39707  INCIDENTE GRAVE            CANUTAMA  AM  BRASIL      <NA>
# 6762       40215        INCIDENTE               COARI  AM  BRASIL      SBUY
# 6763       39807        INCIDENTE            SALVADOR  BA  BRASIL      <NA>
# 6764       40324        INCIDENTE             PELOTAS  RS  BRASIL      SBPK
# 6765       39527         ACIDENTE  LUCAS DO RIO VERDE  MT  BRASIL      <NA>
# 6766       40211        INCIDENTE      RIO DE JANEIRO  RJ  BRASIL      <NA>
# 6767       40349        INCIDENTE               BELÉM  PA  BRASIL      SBBE
# 6768       40351        INCIDENTE      RIO DE JANEIRO  RJ  BRASIL      SBRJ
#
#             dia   horario  recomendacoes  n_aeronaves saida_pista
# 6759 2010-01-10  14:50:00              8            1         NÃO
# 6760 2010-01-10  03:00:00              0            1         NÃO
# 6761 2010-01-09  12:30:00              3            1         NÃO
# 6762 2010-01-07  18:40:00              0            1         SIM
# 6763 2010-01-06  17:53:00              0            1         NÃO
# 6764 2010-01-05  19:25:00              0            1         NÃO
# 6765 2010-01-04  17:30:00              0            1         NÃO
# 6766 2010-01-03  12:00:00              0            1         NÃO
# 6767 2010-01-03  11:05:00              0            1         NÃO
# 6768 2010-01-03  03:00:00              0            1         NÃO

# %%
df.loc[0]
# Out:
# ocorrencia                     81027
# classificacao        INCIDENTE GRAVE
# cidade                     SÃO PAULO
# uf                                SP
# pais                          BRASIL
# aerodromo                       SBSP
# dia              2022-10-09 00:00:00
# horario                     16:30:00
# recomendacoes                      0
# n_aeronaves                        1
# saida_pista                      SIM
# Name: 0, dtype: object

# %%
#consulta dados "Invalidos"
df.isna().sum()
# Out:
# ocorrencia          0
# classificacao       0
# cidade              0
# uf                  4
# pais                0
# aerodromo        2618
# dia                 0
# horario             2
# recomendacoes       0
# n_aeronaves         0
# saida_pista         0
# dtype: int64

# %%
#consulta dados "validos"
df.count()
# Out:
# ocorrencia       6769
# classificacao    6769
# cidade           6769
# uf               6765
# pais             6769
# aerodromo        4151
# dia              6769
# horario          6767
# recomendacoes    6769
# n_aeronaves      6769
# saida_pista      6769
# dtype: int64

# %% [markdown]
# #Filtros

# %%
filtrouf = df.uf.isna()
filtrohorario = df.horario.isna()

# %%
df.loc[filtrouf]
# Out:
#       ocorrencia classificacao                cidade    uf    pais aerodromo  \
# 283        80665      ACIDENTE      NÃO IDENTIFICADA  <NA>  BRASIL      <NA>
# 320        80631     INCIDENTE      NÃO IDENTIFICADA  <NA>  BRASIL      <NA>
# 912        79956      ACIDENTE      NÃO IDENTIFICADA  <NA>  BRASIL      <NA>
# 4541       49474      ACIDENTE  ÁGUAS INTERNACIONAIS  <NA>  BRASIL      <NA>
#
#             dia   horario  recomendacoes  n_aeronaves saida_pista
# 283  2022-04-22  20:00:00              0            1         NÃO
# 320  2022-04-04  11:15:00              0            1         NÃO
# 912  2021-02-26  11:00:00              0            1         NÃO
# 4541 2013-09-02  02:54:00              0            1         NÃO

# %%
df.loc[filtrohorario]
# Out:
#       ocorrencia classificacao   cidade  uf    pais aerodromo        dia  \
# 56         80938     INCIDENTE   MARABÁ  PA  BRASIL      SBMA 2022-08-29
# 2671       78823     INCIDENTE  CORUMBÁ  MS  BRASIL      <NA> 2017-07-09
#
#      horario  recomendacoes  n_aeronaves saida_pista
# 56       NaN              0            1         NÃO
# 2671     NaN              0            1         NÃO

# %% [markdown]
# ---

# %% [markdown]
# #Back de colunas

# %%
df['back_cidade'] = df.cidade

# %% [markdown]
# #24/11 - convertendo as colunas

# %%
df.replace(['****','**NI'], pd.NA, inplace=True)

# %%
#nova
df.replace(pd.NA,np.NaN,inplace=True)

# %%
#converter colunas dia
df['dia'] = df['dia'].astype(str)

# %%
#criar a coluna de data 
df['data'] = pd.to_datetime(df['dia']+ ' ' + df['horario'])

# %%
df.drop(['dia','horario'], axis = 1, inplace = True)

# %%
#arrumar a coluna de lugar
df2 = df [['ocorrencia', 'data', 'aerodromo', 'cidade', 'uf', 'classificacao', 'n_aeronaves','saida_pista']]

# %%
df2.head(2)

# %%
df.dtypes
# Out:
# ocorrencia                int64
# classificacao            object
# cidade                   object
# uf                       object
# pais                     object
# aerodromo                object
# recomendacoes             int64
# n_aeronaves               int64
# saida_pista              object
# back_cidade              object
# data             datetime64[ns]
# dtype: object

# %%
# region filters
#ftsul = df.uf.isin(['RS','PR', 'SC'])
#ftsudeste = df.uf.isin(['ES','MG', 'RJ', 'SP'])
#ftco = df.uf.isin(['DF','GO', 'MT', 'MS'])
#ftnordeste = df.uf.isin(['AL','BA', 'CE', 'MA', 'PB', 'PI', 'PE', 'RN', 'SE'])
#ftnorte = df.uf.isin(['AC','AP', 'AM', 'PA', 'RO', 'RR', 'TO'])

# %% [markdown]
# # Validação

# %%
df.dtypes
# Out:
# ocorrencia                int64
# classificacao            object
# cidade                   object
# uf                       object
# pais                     object
# aerodromo                object
# dia              datetime64[ns]
# horario                  object
# recomendacoes             int64
# n_aeronaves               int64
# saida_pista              object
# back_cidade              object
# dtype: object

# %%
#criação de schema de validação dos dados 

schema = pa.DataFrameSchema(
    columns ={
        'classificacao':pa.Column(pa.String),
        'ocorrencia':pa.Column(pa.Int),
        'cidade':pa.Column(pa.String),
        'uf':pa.Column(pa.String,pa.Check.str_length(2,2), nullable=True),
        'pais':pa.Column(pa.String),
        'aerodromo':pa.Column(pa.String, pa.Check.str_length(4,4), nullable=True),
        'dia':pa.Column(pa.DateTime),
        'horario':pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9]):([0-5][0-9])?$'), nullable=True),
        'recomendacoes':pa.Column(pa.Int),
        'n_aeronaves':pa.Column(pa.Int),
        'saida_pista' :pa.Column(pa.String, pa.Check.str_length(3,3)),


    }
)

# %%
#validador do DF
schema.validate(df)
# Out:
#       ocorrencia    classificacao              cidade  uf    pais aerodromo  \
# 0          81027  INCIDENTE GRAVE           SÃO PAULO  SP  BRASIL      SBSP
# 1          81030        INCIDENTE             VITÓRIA  ES  BRASIL      SBVT
# 2          81023  INCIDENTE GRAVE           AMERICANA  SP  BRASIL      SDAI
# 3          81029        INCIDENTE      BELO HORIZONTE  MG  BRASIL      SBBH
# 4          81025        INCIDENTE              MANAUS  AM  BRASIL      SBEG
# ...          ...              ...                 ...  ..     ...       ...
# 6764       40324        INCIDENTE             PELOTAS  RS  BRASIL      SBPK
# 6765       39527         ACIDENTE  LUCAS DO RIO VERDE  MT  BRASIL      <NA>
# 6766       40211        INCIDENTE      RIO DE JANEIRO  RJ  BRASIL      <NA>
# 6767       40349        INCIDENTE               BELÉM  PA  BRASIL      SBBE
# 6768       40351        INCIDENTE      RIO DE JANEIRO  RJ  BRASIL      SBRJ
#
#             dia   horario  recomendacoes  n_aeronaves saida_pista  \
# 0    2022-10-09  16:30:00              0            1         SIM
# 1    2022-10-09  16:20:00              0            1         NÃO
# 2    2022-10-06  15:30:00              0            1         SIM
# 3    2022-10-06  00:44:00              0            1         NÃO
# 4    2022-10-05  20:56:00              0            1         NÃO
# ...         ...       ...            ...          ...         ...
# 6764 2010-01-05  19:25:00              0            1         NÃO
# 6765 2010-01-04  17:30:00              0            1         NÃO
# 6766 2010-01-03  12:00:00              0            1         NÃO
# 6767 2010-01-03  11:05:00              0            1         NÃO
# 6768 2010-01-03  03:00:00              0            1         NÃO
#
#              back_cidade
# 0              SÃO PAULO
# 1                VITÓRIA
# 2              AMERICANA
# 3         BELO HORIZONTE
# 4                 MANAUS
# ...                  ...
# 6764             PELOTAS
# 6765  LUCAS DO RIO VERDE
# 6766      RIO DE JANEIRO
# 6767               BELÉM
# 6768      RIO DE JANEIRO
#
# [6769 rows x 12 columns]

# %%
#
df.isna().sum()
# Out:
# ocorrencia          0
# classificacao       0
# cidade              0
# uf                  4
# pais                0
# aerodromo        2618
# dia                 0
# horario             2
# recomendacoes       0
# n_aeronaves         0
# saida_pista         0
# back_cidade         0
# dtype: int64

# %% [markdown]
# # outros filtros (especificos)

# %%
filtrouf = df.uf.isna()
filtrohorario = df.horario.isna()

# %%
df.loc[filtrouf]
# Out:
#       ocorrencia classificacao                cidade    uf    pais aerodromo  \
# 283        80665      ACIDENTE      NÃO IDENTIFICADA  <NA>  BRASIL      <NA>
# 320        80631     INCIDENTE      NÃO IDENTIFICADA  <NA>  BRASIL      <NA>
# 912        79956      ACIDENTE      NÃO IDENTIFICADA  <NA>  BRASIL      <NA>
# 4541       49474      ACIDENTE  ÁGUAS INTERNACIONAIS  <NA>  BRASIL      <NA>
#
#             dia   horario  recomendacoes  n_aeronaves saida_pista  \
# 283  2022-04-22  20:00:00              0            1         NÃO
# 320  2022-04-04  11:15:00              0            1         NÃO
# 912  2021-02-26  11:00:00              0            1         NÃO
# 4541 2013-09-02  02:54:00              0            1         NÃO
#
#                back_cidade
# 283       NÃO IDENTIFICADA
# 320       NÃO IDENTIFICADA
# 912       NÃO IDENTIFICADA
# 4541  ÁGUAS INTERNACIONAIS

# %%
df.loc[filtrohorario]
# Out:
#       ocorrencia classificacao   cidade  uf    pais aerodromo        dia  \
# 56         80938     INCIDENTE   MARABÁ  PA  BRASIL      SBMA 2022-08-29
# 2671       78823     INCIDENTE  CORUMBÁ  MS  BRASIL      <NA> 2017-07-09
#
#      horario  recomendacoes  n_aeronaves saida_pista back_cidade
# 56       NaN              0            1         NÃO      MARABÁ
# 2671     NaN              0            1         NÃO     CORUMBÁ

# %%
filtrosp = df.uf == "SP"

# %%
ftincidente = df.classificacao == 'INCIDENTE'
ftano = df.dia.dt.year == 2021
ftsp = df.uf == 'SP'

# %%
#exemplode nome para salvar oum filtro especifico 
dfosni = df.loc[ftsp & ftano]

# %%
dfosni
# Out:
#       ocorrencia    classificacao     cidade  uf    pais aerodromo        dia  \
# 460        80452         ACIDENTE    MARACAÍ  SP  BRASIL      <NA> 2021-12-31
# 465        80456        INCIDENTE  SÃO PAULO  SP  BRASIL      SBSP 2021-12-30
# 467        80453        INCIDENTE   CAMPINAS  SP  BRASIL      SBKP 2021-12-29
# 468        80454  INCIDENTE GRAVE  ARAÇATUBA  SP  BRASIL      SBAU 2021-12-29
# 476        80545        INCIDENTE  GUARULHOS  SP  BRASIL      SBGR 2021-12-22
# ...          ...              ...        ...  ..     ...       ...        ...
# 994        79816        INCIDENTE  GUARULHOS  SP  BRASIL      SBGR 2021-01-11
# 1001       79805        INCIDENTE  GUARULHOS  SP  BRASIL      SBGR 2021-01-07
# 1005       79809        INCIDENTE  GUARULHOS  SP  BRASIL      SBGR 2021-01-06
# 1008       79798         ACIDENTE      GUARÁ  SP  BRASIL      <NA> 2021-01-05
# 1013       79758        INCIDENTE  SÃO PAULO  SP  BRASIL      <NA> 2021-01-02
#
#        horario  recomendacoes  n_aeronaves saida_pista back_cidade
# 460   09:30:00              0            1         NÃO     MARACAÍ
# 465   13:15:00              0            1         SIM   SÃO PAULO
# 467   09:00:00              0            1         NÃO    CAMPINAS
# 468   21:35:00              0            1         SIM   ARAÇATUBA
# 476   11:50:00              0            1         NÃO   GUARULHOS
# ...        ...            ...          ...         ...         ...
# 994   11:50:00              0            1         NÃO   GUARULHOS
# 1001  02:05:00              0            1         NÃO   GUARULHOS
# 1005  12:48:00              0            1         NÃO   GUARULHOS
# 1008  20:30:00              0            1         NÃO       GUARÁ
# 1013  18:30:00              0            1         NÃO   SÃO PAULO
#
# [137 rows x 12 columns]

# %% [markdown]
# #Filtro 23/11

# %%
#filtra os valores nulos ou ausentes | NA, NULL, NaN,NaT E ETEC
filtronulo = df.aerodromo.isna()
df.loc[filtronulo]
# Out:
#       ocorrencia    classificacao              cidade  uf    pais aerodromo  \
# 5          81019         ACIDENTE        PORTO ALEGRE  RS  BRASIL      <NA>
# 6          81022        INCIDENTE              LOBATO  PR  BRASIL      <NA>
# 7          81021         ACIDENTE   NOVA BANDEIRANTES  MT  BRASIL      <NA>
# 8          81009  INCIDENTE GRAVE             NAVIRAÍ  MS  BRASIL      <NA>
# 9          81012        INCIDENTE            LINHARES  ES  BRASIL      <NA>
# ...          ...              ...                 ...  ..     ...       ...
# 6758       39789        INCIDENTE    SÃO PEDRO DO SUL  RS  BRASIL      <NA>
# 6761       39707  INCIDENTE GRAVE            CANUTAMA  AM  BRASIL      <NA>
# 6763       39807        INCIDENTE            SALVADOR  BA  BRASIL      <NA>
# 6765       39527         ACIDENTE  LUCAS DO RIO VERDE  MT  BRASIL      <NA>
# 6766       40211        INCIDENTE      RIO DE JANEIRO  RJ  BRASIL      <NA>
#
#             dia   horario  recomendacoes  n_aeronaves saida_pista  \
# 5    2022-10-03  20:50:00              0            1         NÃO
# 6    2022-10-03  15:38:00              0            1         NÃO
# 7    2022-10-02  19:00:00              0            1         SIM
# 8    2022-10-01  10:10:00              0            1         SIM
# 9    2022-09-30  12:20:00              0            1         NÃO
# ...         ...       ...            ...          ...         ...
# 6758 2010-01-10  21:30:00              0            1         NÃO
# 6761 2010-01-09  12:30:00              3            1         NÃO
# 6763 2010-01-06  17:53:00              0            1         NÃO
# 6765 2010-01-04  17:30:00              0            1         NÃO
# 6766 2010-01-03  12:00:00              0            1         NÃO
#
#              back_cidade
# 5           PORTO ALEGRE
# 6                 LOBATO
# 7      NOVA BANDEIRANTES
# 8                NAVIRAÍ
# 9               LINHARES
# ...                  ...
# 6758    SÃO PEDRO DO SUL
# 6761            CANUTAMA
# 6763            SALVADOR
# 6765  LUCAS DO RIO VERDE
# 6766      RIO DE JANEIRO
#
# [2618 rows x 12 columns]

# %%
#filtro de classificacao
filtroacidente = df.classificacao == 'ACIDENTE'
dfacidente = df.loc[filtroacidente]

# %%
#filtro mais detalhado
ftcidade = df.cidade == 'SÃO PAULO'
ftpista = df.saida_pista =='SIM'
ft2020 = df.dia.dt.year == 2020
df.loc[ftcidade & ftpista & ft2020]
# Out:
#       ocorrencia    classificacao     cidade  uf    pais aerodromo        dia  \
# 1050       79718  INCIDENTE GRAVE  SÃO PAULO  SP  BRASIL      SBMT 2020-12-11
#
#        horario  recomendacoes  n_aeronaves saida_pista back_cidade
# 1050  13:50:00              0            1         SIM   SÃO PAULO

# %%
ftsul = df.uf.isin(['RS','PR','SC'])
df.loc[ftsul & filtroacidente]
# Out:
#       ocorrencia classificacao            cidade  uf    pais aerodromo  \
# 5          81019      ACIDENTE      PORTO ALEGRE  RS  BRASIL      <NA>
# 15         81018      ACIDENTE           LONTRAS  SC  BRASIL      <NA>
# 48         80954      ACIDENTE        NAVEGANTES  SC  BRASIL      SBNF
# 52         80952      ACIDENTE   ELDORADO DO SUL  RS  BRASIL      SSMK
# 62         80942      ACIDENTE       CAMPO LARGO  PR  BRASIL      <NA>
# ...          ...           ...               ...  ..     ...       ...
# 6574       41053      ACIDENTE          CASCAVEL  PR  BRASIL      SBCA
# 6611       40572      ACIDENTE      PORTO ALEGRE  RS  BRASIL      SBPA
# 6644       40147      ACIDENTE  UNIÃO DA VITÓRIA  PR  BRASIL      SSUV
# 6723       39316      ACIDENTE      RIO DO OESTE  SC  BRASIL      <NA>
# 6744       39320      ACIDENTE             FAROL  PR  BRASIL      <NA>
#
#             dia   horario  recomendacoes  n_aeronaves saida_pista  \
# 5    2022-10-03  20:50:00              0            1         NÃO
# 15   2022-09-24  20:05:00              0            1         NÃO
# 48   2022-09-02  11:40:00              0            1         NÃO
# 52   2022-09-01  18:00:00              0            1         NÃO
# 62   2022-08-27  20:30:00              0            1         NÃO
# ...         ...       ...            ...          ...         ...
# 6574 2010-05-19  08:10:00              2            1         NÃO
# 6611 2010-04-28  14:10:00              0            1         NÃO
# 6644 2010-04-08  14:20:00              3            1         SIM
# 6723 2010-02-04  17:55:00              2            1         NÃO
# 6744 2010-01-19  18:30:00              4            1         NÃO
#
#            back_cidade
# 5         PORTO ALEGRE
# 15             LONTRAS
# 48          NAVEGANTES
# 52     ELDORADO DO SUL
# 62         CAMPO LARGO
# ...                ...
# 6574          CASCAVEL
# 6611      PORTO ALEGRE
# 6644  UNIÃO DA VITÓRIA
# 6723      RIO DO OESTE
# 6744             FAROL
#
# [412 rows x 12 columns]

# %%
#filtro de datas certas - por datas
ftagosto = df.dia.dt.month == 8
ftquinz = (df.dia.dt.day > 0) & (df.dia.dt.day < 16)
df.loc[ftagosto & ftquinz]
# Out:
#       ocorrencia classificacao              cidade  uf    pais aerodromo  \
# 82         80915     INCIDENTE             GOIÂNIA  GO  BRASIL      SBGO
# 83         80919     INCIDENTE            SOROCABA  SP  BRASIL      SDCO
# 84         80920      ACIDENTE      RIO DE JANEIRO  RJ  BRASIL      <NA>
# 85         81008     INCIDENTE           GUARULHOS  SP  BRASIL      SBGR
# 86         80921      ACIDENTE            SÃO LUÍS  MA  BRASIL      <NA>
# ...          ...           ...                 ...  ..     ...       ...
# 6460       42449      ACIDENTE  SÃO FÉLIX DO XINGU  PA  BRASIL      <NA>
# 6461       42286     INCIDENTE              CUIABÁ  MT  BRASIL      <NA>
# 6462       42446     INCIDENTE               BAURU  SP  BRASIL      SBAE
# 6463       42626     INCIDENTE            CURITIBA  PR  BRASIL      <NA>
# 6464       42590     INCIDENTE            SÃO LUÍS  MA  BRASIL      SBSL
#
#             dia   horario  recomendacoes  n_aeronaves saida_pista  \
# 82   2022-08-15  09:25:00              0            1         NÃO
# 83   2022-08-15  11:30:00              0            1         NÃO
# 84   2022-08-15  18:30:00              0            1         NÃO
# 85   2022-08-15  03:15:00              0            1         NÃO
# 86   2022-08-14  19:00:00              0            1         NÃO
# ...         ...       ...            ...          ...         ...
# 6460 2010-08-03  16:20:00              8            1         NÃO
# 6461 2010-08-02  10:00:00              0            1         NÃO
# 6462 2010-08-02  11:04:00              0            1         NÃO
# 6463 2010-08-02  01:40:00              0            1         NÃO
# 6464 2010-08-01  18:50:00              0            1         NÃO
#
#              back_cidade
# 82               GOIÂNIA
# 83              SOROCABA
# 84        RIO DE JANEIRO
# 85             GUARULHOS
# 86              SÃO LUÍS
# ...                  ...
# 6460  SÃO FÉLIX DO XINGU
# 6461              CUIABÁ
# 6462               BAURU
# 6463            CURITIBA
# 6464            SÃO LUÍS
#
# [267 rows x 12 columns]

# %% [markdown]
# # Group by

# %%
df.groupby(['uf'], dropna = False).size().sort_values(ascending=False)
# Out:
# uf
# SP     1625
# MG      638
# RJ      578
# PR      548
# RS      395
# GO      359
# MT      359
# PA      344
# AM      279
# BA      253
# SC      223
# MS      191
# DF      156
# PE      126
# CE       95
# ES       91
# MA       86
# RR       73
# AC       66
# TO       60
# RO       54
# PI       45
# AL       34
# PB       28
# SE       22
# RN       22
# AP       15
# NaN       4
# dtype: int64

# %% [markdown]
# #Teste de Grupo By

# %%
df.groupby(['classificacao']).size().sort_values(ascending=False)
# Out:
# classificacao
# INCIDENTE          3795
# ACIDENTE           2090
# INCIDENTE GRAVE     884
# dtype: int64

# %%
df.groupby(['uf'],dropna=False).size().sort_values(ascending=False)
# Out:
# uf
# SP     1625
# MG      638
# RJ      578
# PR      548
# RS      395
# GO      359
# MT      359
# PA      344
# AM      279
# BA      253
# SC      223
# MS      191
# DF      156
# PE      126
# CE       95
# ES       91
# MA       86
# RR       73
# AC       66
# TO       60
# RO       54
# PI       45
# AL       34
# PB       28
# SE       22
# RN       22
# AP       15
# NaN       4
# dtype: int64

# %%
df.groupby(['aerodromo'],dropna=False).size().sort_values(ascending=False)
# Out:
# aerodromo
# NaN     2618
# SBGR     173
# SBMT     150
# SBKP     128
# SBBH     124
#         ...
# SJVL       1
# SJTO       1
# SJOD       1
# SJNQ       1
# SJNC       1
# Length: 574, dtype: int64
