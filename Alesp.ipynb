# %% [markdown]
# <a href="https://colab.research.google.com/github/Stesilva16/Eng-de-dados--/blob/main/Alesp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://storage.googleapis.com/bc26-bucket/despesa_alesp.csv')

# %%
df
# Out:
#          Ano  Matricula  Mes    Valor          CNPJ  \
# 0       2013     300098    1   575.53  5.049700e+11
# 1       2013     300098    1  1650.76  4.881450e+13
# 2       2013     300098    1  1799.29  6.586291e+13
# 3       2013     300098    1    36.40           NaN
# 4       2013     300098    1  3100.00  9.904660e+11
# ...      ...        ...  ...      ...           ...
# 118412  2022     300655    9  1250.00  1.531481e+13
# 118413  2022     300655    9  2500.00  6.729494e+10
# 118414  2022     300655    9   599.29  4.639213e+13
# 118415  2022     300655    9  1836.13  6.106391e+13
# 118416  2022     300655    9  2835.90  2.491558e+12
#
#                                                      Tipo  \
# 0                        A - COMBUSTÍVEIS E LUBRIFICANTES
# 1                        A - COMBUSTÍVEIS E LUBRIFICANTES
# 2                        A - COMBUSTÍVEIS E LUBRIFICANTES
# 3       C - MATERIAIS E SERVIÇOS DE MANUT E CONSERV DE...
# ...

# %%
pd.unique(df['Tipo'])
# Out:
# array(['A - COMBUSTÍVEIS E LUBRIFICANTES',
#        'C - MATERIAIS E SERVIÇOS DE MANUT E CONSERV DE VEÍCULOS ; PEDÁGIOS',
#        'D - MATERIAIS E SERVIÇOS GRÁFICOS, DE CÓPIAS  E REPRODUÇÃO DE DOCS',
#        'E - MATERIAIS DE ESCRITÓRIO E OUTROS MATERIAIS DE CONSUMO',
#        'G - ASSINATURAS DE PERIÓDICOS, PUBLICAÇÕES, INTERNET E SOFTWARES',
#        'H - SERV.UTIL.PÚBLICA (TELEF.MÓVEL/FIXA, ENERGIA, ÁGUA, GÁS ETC)',
#        'I - HOSPEDAGEM, ALIMENTAÇÃO E DESPESAS DE LOCOMOÇÃO',
#        'J - SERVIÇOS DE COMUNICAÇÃO', 'L - LOCAÇÃO DE BENS IMÓVEIS',
#        'M - MANUTENÇÃO DE BENS MÓVEIS,  IMÓVEIS, CONDOMÍNIOS E OUTROS',
#        'N - MORADIA',
#        'F - SERVIÇOS TÉCNICOS PROFISSIONAIS (CONSULTORIA, PESQUISAS ETC)',
#        'O - LOCAÇÃO DE VEÍCULO',
#        'P - DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR',
#        'K - LOCAÇÃO DE BENS MÓVEIS'], dtype=object)

# %%
filtro = df.Tipo == 'C - MATERIAIS E SERVIÇOS DE MANUT E CONSERV DE VEÍCULOS ; PEDÁGIOS'

# %%
dped = df.loc[filtro]

# %%
dped
# Out:
#          Ano  Matricula  Mes  Valor          CNPJ  \
# 3       2013     300098    1   36.4           NaN
# 26      2013     300098    2   30.0  6.116149e+13
# 27      2013     300098    2   10.4           NaN
# 60      2013     300098    3  374.4  1.845323e+12
# 61      2013     300098    3  230.0  6.553230e+13
# ...      ...        ...  ...    ...           ...
# 117309  2021     300650   11  115.2           NaN
# 117374  2022     300650    1   30.4           NaN
# 117433  2022     300650    3   53.0           NaN
# 117590  2022     300650    8  398.9           NaN
# 117819  2022     300653    2  639.4  1.669964e+13
#
#                                                      Tipo  \
# 3       C - MATERIAIS E SERVIÇOS DE MANUT E CONSERV DE...
# 26      C - MATERIAIS E SERVIÇOS DE MANUT E CONSERV DE...
# 27      C - MATERIAIS E SERVIÇOS DE MANUT E CONSERV DE...
# 60      C - MATERIAIS E SERVIÇOS DE MANUT E CONSERV DE...
# 61      C - MATERIAIS E SERVIÇOS DE MANUT E CONSERV DE...
# ...

# %%
df.dtypes
# Out:
# Ano             int64
# Matricula       int64
# Mes             int64
# Valor         float64
# CNPJ          float64
# Tipo           object
# Fornecedor     object
# dtype: object

# %%
filtro2 = dped.Fornecedor.str.contains('PED|PEG')

# %%
filtro3 = dped.Fornecedor.str[-2:] == 'PE'

# %%
novo = dped.loc[filtro2]

# %%
df.replace(['PEDÁGIO', 'CUPONS DE PEDÁGIO', 'PEDAGIO DE ELISIARIO', 'PEDAGIO',
       'PEGAGIO', 'PRAÇA DE PEDÁGIO DE GUARUJÁ', 'PEDÁGIOS'],'PEDAGIO',inplace=True)
# Out:
#          Ano  Matricula  Mes    Valor          CNPJ  \
# 0       2013     300098    1   575.53  5.049700e+11
# 1       2013     300098    1  1650.76  4.881450e+13
# 2       2013     300098    1  1799.29  6.586291e+13
# 3       2013     300098    1    36.40           NaN
# 4       2013     300098    1  3100.00  9.904660e+11
# ...      ...        ...  ...      ...           ...
# 118412  2022     300655    9  1250.00  1.531481e+13
# 118413  2022     300655    9  2500.00  6.729494e+10
# 118414  2022     300655    9   599.29  4.639213e+13
# 118415  2022     300655    9  1836.13  6.106391e+13
# 118416  2022     300655    9  2835.90  2.491558e+12
#
#                                                      Tipo  \
# 0                        A - COMBUSTÍVEIS E LUBRIFICANTES
# 1                        A - COMBUSTÍVEIS E LUBRIFICANTES
# 2                        A - COMBUSTÍVEIS E LUBRIFICANTES
# 3       C - MATERIAIS E SERVIÇOS DE MANUT E CONSERV DE...
# ...

# %%
pd.unique(novo['Fornecedor'])
# Out:
# array(['PEDÁGIO', 'CUPONS DE PEDÁGIO', 'PEDAGIO DE ELISIARIO', 'PEDAGIO',
#        'PEGAGIO', 'PRAÇA DE PEDÁGIO DE GUARUJÁ', 'PEDÁGIOS'], dtype=object)

# %%
sorted(pd.unique(df['Fornecedor']))

# %%
df2 = pd.read_csv('https://storage.googleapis.com/bc26-bucket/cadastro_alesp.csv')

# %%
df2
# Out:
#     IdDeputado       IdSPL   IdUA Situacao     Andar Aniversario  \
# 0          549  1000000330  20377      EXE  3º andar       01/11
# 1          548  1000000332  20370      EXE    Térreo       09/07
# 2          547  1000000335  20455      EXE  2º andar       26/08
# 3          128          39  20369      EXE        3º       04/01
# 4          546  1000000342  20399      EXE        1º       17/09
# ..         ...         ...    ...      ...       ...         ...
# 88         289       13109  20414      EXE        1º       08/07
# 89         504  1000000373  20400      EXE  3º andar       23/04
# 90         503  1000000374  20447      EXE    Térreo       16/09
# 91          13         448  20394      EXE    Térreo       06/11
# 92         290       13098  20405      EXE  2º andar       22/01
#
#                                             Biografia  \
# 0   <p style="margin: 0cm 0cm 0.0001pt; background...
# 1   <p class="MsoNormal">Com uma hist&oacute;ria d...
# ...
